# %% [markdown]
# <h1>DATA ANALYSIS OF NEW YORK CITI BIKERS IN PYTHON AND SQL </h1>

# %% [markdown]
# # Install software libraries

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from seaborn) (1.21.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\kemik\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %% [markdown]
# # Import software libraries

# %%
import pandas as pd
import sqlalchemy
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# %load_ext sql

# %% [markdown]
# # Create a SQLite database

# %%
engine = sqlalchemy.create_engine('sqlite:///citibikes.db')

# %% [markdown]
# # Connect to the SQLite database

# %%
# %sql sqlite:///citibikes.db

# %% [markdown]
# # Load the dataset as a `DataFrame`

# %%
NY_Citi_Bikes_data=pd.read_csv('Datasets/New York Citi Bikes_Raw Data - NYCitiBikes (1).csv')

# %%
NY_Citi_Bikes_data.head(3)
# Out:
#        Start Time       Stop Time  Start Station ID Start Station Name  \
# 0  01-01-17 00:38    1-1-17 01:03              3194    McGinley Square
# 1  01-01-17 01:47  01-01-17 01:58              3183     Exchange Place
# 2  01-01-17 01:47  01-01-17 01:58              3183     Exchange Place
#
#    End Station ID     End Station Name  Bike ID   User Type  Birth Year  Age  \
# 0            3271  Danforth Light Rail    24668  Subscriber        1961   60
# 1            3203        Hamilton Park    26167  Subscriber        1993   28
# 2            3203        Hamilton Park    26167  Subscriber        1993   28
#
#   Age Groups  Trip Duration Trip_Duration_in_min  Month  Season  Temperature  \
# 0      55-64           1513                   25      1  Winter           10
# 1      25-34            639                   11      1  Winter           10
# 2      25-34            639                   11      1  Winter           10
#
#   Weekday
# 0  Sunday
# 1  Sunday
# 2  Sunday

# %% [markdown]
# # Store the DataFrame in the SQLite database

# %%
NY_Citi_Bikes_data.to_sql('NYCitiBikesdata', con=engine, if_exists='replace')
# Out:
# 20400

# %% [markdown]
# # Connect to the sqlite database

# %%
conn = sqlite3.connect('citibikes.db')

# %%
cursor=conn.cursor()

# %% [markdown]
# # Get the list of tables and columns from the database

# %%
cursor.execute('''select name from sqlite_master where type='table';''')
print('List of tables present in the database')
table_list=[table[0]for table in cursor.fetchall()]
table_list
# Out:
# List of tables present in the database
# ['CleanedNYCitiBikesdata', 'NYCitiBikesdata']

# %%
for table in table_list:
    print("\ntable: " + table)
    columns_info= conn.execute("PRAGMA table_info({})".format(table))
    for column in columns_info.fetchall():
        print(column[1:3])
# Out:
# table: CleanedNYCitiBikesdata
# ('level_0', 'BIGINT')
# ('index', 'BIGINT')
# ('Start Time', 'TEXT')
# ('Stop Time', 'TEXT')
# ('Start Station ID', 'BIGINT')
# ('Start Station Name', 'TEXT')
# ('End Station ID', 'BIGINT')
# ('End Station Name', 'TEXT')
# ('Bike ID', 'BIGINT')
# ('User Type', 'TEXT')
# ('Birth Year', 'BIGINT')
# ('Age', 'BIGINT')
# ('Age Groups', 'TEXT')
# ('Trip Duration', 'BIGINT')
# ('Trip_Duration_in_min', 'BIGINT')
# ('Month', 'BIGINT')
# ('Season', 'TEXT')
# ('Temperature', 'BIGINT')
# ('Weekday', 'TEXT')
#
# table: NYCitiBikesdata
# ('index', 'BIGINT')
# ('Start Time', 'TEXT')
# ('Stop Time', 'TEXT')
# ('Start Station ID', 'BIGINT')
# ('Start Station Name', 'TEXT')
# ('End Station ID', 'BIGINT')
# ('End Station Name', 'TEXT')
# ('Bike ID', 'BIGINT')
# ('User Type', 'TEXT')
# ('Birth Year', 'BIGINT')
# ('Age', 'BIGINT')
# ('Age Groups', 'TEXT')
# ('Trip Duration', 'BIGINT')
# ('Trip_Duration_in_min', 'TEXT')
# ('Month', 'BIGINT')
# ('Season', 'TEXT')
# ('Temperature', 'BIGINT')
# ('Weekday', 'TEXT')

# %%
# Get only the column names
print('\nColumns in NYCitiBikesdata table:')
data=cursor.execute('''SELECT * FROM NYCitiBikesdata''')
for column in data.description:
    print(column[0])
# Out:
# Columns in NYCitiBikesdata table:
# index
# Start Time
# Stop Time
# Start Station ID
# Start Station Name
# End Station ID
# End Station Name
# Bike ID
# User Type
# Birth Year
# Age
# Age Groups
# Trip Duration
# Trip_Duration_in_min
# Month
# Season
# Temperature
# Weekday

# %% [markdown]
# # Read the database as a dataframe

# %%
NY_Citi_Bikes_data = pd.read_sql_query('''select * from NYCitiBikesdata ''', conn)
NY_Citi_Bikes_data.head(3)
# Out:
#    index      Start Time       Stop Time  Start Station ID Start Station Name  \
# 0      0  01-01-17 00:38    1-1-17 01:03              3194    McGinley Square
# 1      1  01-01-17 01:47  01-01-17 01:58              3183     Exchange Place
# 2      2  01-01-17 01:47  01-01-17 01:58              3183     Exchange Place
#
#    End Station ID     End Station Name  Bike ID   User Type  Birth Year  Age  \
# 0            3271  Danforth Light Rail    24668  Subscriber        1961   60
# 1            3203        Hamilton Park    26167  Subscriber        1993   28
# 2            3203        Hamilton Park    26167  Subscriber        1993   28
#
#   Age Groups  Trip Duration Trip_Duration_in_min  Month  Season  Temperature  \
# 0      55-64           1513                   25      1  Winter           10
# 1      25-34            639                   11      1  Winter           10
# 2      25-34            639                   11      1  Winter           10
#
#   Weekday
# 0  Sunday
# 1  Sunday
# 2  Sunday

# %%
NY_Citi_Bikes_data_wt_duplicates = pd.read_sql_query('''
                                       SELECT DISTINCT * FROM NYCitiBikesdata
                                       GROUP BY `Start Time`,`Stop Time`, `Start Station ID`,`Start Station Name`,
                                       `End Station ID`, `End Station Name`,`Bike ID`, `User Type`,`Birth Year`,
                                       `Age`, `Age Groups`,`Trip Duration`, `Trip_Duration_in_min`,`Month`,
                                       `Season`, `Temperature`, `Weekday`
                                        HAVING COUNT(*)=1
                                        ''', conn)
NY_Citi_Bikes_data_wt_duplicates
# Out:
#        index      Start Time       Stop Time  Start Station ID  \
# 0          0  01-01-17 00:38    1-1-17 01:03              3194
# 1          3  01-01-17 01:56  01-01-17 02:00              3186
# 2          5  01-01-17 02:22    1-1-17 02:31              3212
# 3          6  01-01-17 02:23  01-01-17 02:27              3186
# 4         11  01-01-17 06:29  01-01-17 06:31              3186
# ...      ...             ...             ...               ...
# 16606  14832    9-3-17 20:48  09-03-17 20:50              3273
# 16607  14833    9-3-17 20:48  09-03-17 21:00              3187
# 16608  14841    9-3-17 21:19  09-03-17 21:23              3275
# 16609  14844    9-3-17 21:23  09-03-17 21:30              3220
# 16610  14851    9-3-17 22:05  09-03-17 22:08              3186
#
#       Start Station Name  End Station ID       End Station Name  Bike ID  \
# 0        McGinley Square            3271    Danforth Light Rail    24668
# 1          Grove St PATH            3270        Jersey & 6th St    24604
# 2        Christ Hospital            3225  Baldwin at Montgomery    24520
# 3          Grove St PATH            3203          Hamilton Park    24512
# 4          Grove St PATH            3211             Newark Ave    24681
# ...                  ...             ...                    ...      ...
# 16606       Manila & 1st            3211             Newark Ave    24609
# 16607          Warren St            3220      5 Corners Library    24528
# 16608     Columbus Drive            3184            Paulus Hook    24617
# 16609  5 Corners Library            3281    Leonard Gordon Park    24528
# 16610      Grove St PATH            3270        Jersey & 6th St    24573
#
#         User Type  Birth Year  Age Age Groups  Trip Duration  \
# 0      Subscriber        1961   60      55-64           1513
# 1      Subscriber        1970   51      45-54            258
# 2      Subscriber        1987   34      25-34            535
# 3      Subscriber        1984   37      35-44            224
# 4      Subscriber        1964   57      55-64            107
# ...           ...         ...  ...        ...            ...
# 16606  Subscriber        1964   57      55-64            129
# 16607  Subscriber        1991   30      25-34            743
# 16608  Subscriber        1960   61      55-64            261
# 16609  Subscriber        1996   25      25-34            424
# 16610  Subscriber        1960   61      55-64            206
#
#       Trip_Duration_in_min  Month  Season  Temperature   Weekday
# 0                       25      1  Winter           10    Sunday
# 1                        4      1  Winter           10    Sunday
# 2                        9      1  Winter           10    Sunday
# 3                        4      1  Winter           10    Sunday
# 4                        2      1  Winter           10    Sunday
# ...                    ...    ...     ...          ...       ...
# 16606                    2      3  Spring           19  Thursday
# 16607                   12      3  Spring           19  Thursday
# 16608                    4      3  Spring           19  Thursday
# 16609                    7      3  Spring           19  Thursday
# 16610                    3      3  Spring           19  Thursday
#
# [16611 rows x 18 columns]

# %% [markdown]
# # Identify and handle missing values

# %% [markdown]
# In the dataset, missing data comes with the question mark "?". We replace "?" with NaN (Not a Number), Python's default missing value marker for reasons of computational speed and convenience. Here we use the function:
# .replace(A, B, inplace = True)
# to replace A by B.

# %%
import numpy as np

# replace "?" to NaN
NY_Citi_Bikes_data_wt_duplicates.replace("?", np.nan, inplace = True)

# %% [markdown]
# # Evaluating for Missing Data

# %% [markdown]
# The missing values are converted by default. We use the following functions to identify these missing values. There are two methods to detect missing data:
#
# .isnull()
# .notnull()
# The output is a boolean value indicating whether the value that is passed into the argument is in fact missing data.

# %%
missing_data =NY_Citi_Bikes_data_wt_duplicates.isnull()
missing_data.head(5)
# Out:
#    index  Start Time  Stop Time  Start Station ID  Start Station Name  \
# 0  False       False      False             False               False
# 1  False       False      False             False               False
# 2  False       False      False             False               False
# 3  False       False      False             False               False
# 4  False       False      False             False               False
#
#    End Station ID  End Station Name  Bike ID  User Type  Birth Year    Age  \
# 0           False             False    False      False       False  False
# 1           False             False    False      False       False  False
# 2           False             False    False      False       False  False
# 3           False             False    False      False       False  False
# 4           False             False    False      False       False  False
#
#    Age Groups  Trip Duration  Trip_Duration_in_min  Month  Season  \
# 0       False          False                 False  False   False
# 1       False          False                 False  False   False
# 2       False          False                 False  False   False
# 3       False          False                 False  False   False
# 4       False          False                 False  False   False
#
#    Temperature  Weekday
# 0        False    False
# 1        False    False
# 2        False    False
# 3        False    False
# 4        False    False

# %% [markdown]
# "True" means the value is a missing value while "False" means the value is not a missing value.

# %% [markdown]
# # Count missing values in each column

# %% [markdown]
# Using a for loop in Python, we can quickly figure out the number of missing values in each column. As mentioned above, "True" represents a missing value and "False" means the value is present in the dataset. In the body of the for loop the method ".value_counts()" counts the number of "True" values.

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# index
# index
# False    16611
# Name: count, dtype: int64
#
# Start Time
# Start Time
# False    16611
# Name: count, dtype: int64
#
# Stop Time
# Stop Time
# False    16611
# Name: count, dtype: int64
#
# Start Station ID
# Start Station ID
# False    16611
# Name: count, dtype: int64
#
# Start Station Name
# Start Station Name
# False    16611
# Name: count, dtype: int64
#
# End Station ID
# End Station ID
# False    16611
# Name: count, dtype: int64
#
# End Station Name
# End Station Name
# False    16610
# True         1
# Name: count, dtype: int64
#
# Bike ID
# Bike ID
# False    16611
# Name: count, dtype: int64
#
# User Type
# User Type
# False    16611
# Name: count, dtype: int64
#
# Birth Year
# Birth Year
# False    16611
# Name: count, dtype: int64
#
# Age
# Age
# False    16611
# Name: count, dtype: int64
#
# Age Groups
# Age Groups
# False    16611
# Name: count, dtype: int64
#
# Trip Duration
# Trip Duration
# False    16611
# Name: count, dtype: int64
#
# Trip_Duration_in_min
# Trip_Duration_in_min
# False    16611
# Name: count, dtype: int64
#
# Month
# Month
# False    16611
# Name: count, dtype: int64
#
# Season
# Season
# False    16611
# Name: count, dtype: int64
#
# Temperature
# Temperature
# False    16611
# Name: count, dtype: int64
#
# Weekday
# Weekday
# False    16611
# Name: count, dtype: int64

# %% [markdown]
# Based on the summary above, each column has 16611 rows of data and only one of the columns containing missing data:
#
# <ul>
#     <li>"End Station Name": 1 missing data</li>
# </ul>
# To deal with this missing data, we will be deleting the entire row
# let's drop all rows that do not have End Station Name data

# %%
# Drop whole row with NaN in "End Station Name" column
NY_Citi_Bikes_data_wt_duplicates.dropna(subset=["End Station Name"], axis=0, inplace=True)

# reset index, because we droped one row
NY_Citi_Bikes_data_wt_duplicates.reset_index(drop=True, inplace=True)

# %%
NY_Citi_Bikes_data_wt_duplicates
# Out:
#        index      Start Time       Stop Time  Start Station ID  \
# 0          0  01-01-17 00:38    1-1-17 01:03              3194
# 1          3  01-01-17 01:56  01-01-17 02:00              3186
# 2          5  01-01-17 02:22    1-1-17 02:31              3212
# 3          6  01-01-17 02:23  01-01-17 02:27              3186
# 4         11  01-01-17 06:29  01-01-17 06:31              3186
# ...      ...             ...             ...               ...
# 16605  14832    9-3-17 20:48  09-03-17 20:50              3273
# 16606  14833    9-3-17 20:48  09-03-17 21:00              3187
# 16607  14841    9-3-17 21:19  09-03-17 21:23              3275
# 16608  14844    9-3-17 21:23  09-03-17 21:30              3220
# 16609  14851    9-3-17 22:05  09-03-17 22:08              3186
#
#       Start Station Name  End Station ID       End Station Name  Bike ID  \
# 0        McGinley Square            3271    Danforth Light Rail    24668
# 1          Grove St PATH            3270        Jersey & 6th St    24604
# 2        Christ Hospital            3225  Baldwin at Montgomery    24520
# 3          Grove St PATH            3203          Hamilton Park    24512
# 4          Grove St PATH            3211             Newark Ave    24681
# ...                  ...             ...                    ...      ...
# 16605       Manila & 1st            3211             Newark Ave    24609
# 16606          Warren St            3220      5 Corners Library    24528
# 16607     Columbus Drive            3184            Paulus Hook    24617
# 16608  5 Corners Library            3281    Leonard Gordon Park    24528
# 16609      Grove St PATH            3270        Jersey & 6th St    24573
#
#         User Type  Birth Year  Age Age Groups  Trip Duration  \
# 0      Subscriber        1961   60      55-64           1513
# 1      Subscriber        1970   51      45-54            258
# 2      Subscriber        1987   34      25-34            535
# 3      Subscriber        1984   37      35-44            224
# 4      Subscriber        1964   57      55-64            107
# ...           ...         ...  ...        ...            ...
# 16605  Subscriber        1964   57      55-64            129
# 16606  Subscriber        1991   30      25-34            743
# 16607  Subscriber        1960   61      55-64            261
# 16608  Subscriber        1996   25      25-34            424
# 16609  Subscriber        1960   61      55-64            206
#
#       Trip_Duration_in_min  Month  Season  Temperature   Weekday
# 0                       25      1  Winter           10    Sunday
# 1                        4      1  Winter           10    Sunday
# 2                        9      1  Winter           10    Sunday
# 3                        4      1  Winter           10    Sunday
# 4                        2      1  Winter           10    Sunday
# ...                    ...    ...     ...          ...       ...
# 16605                    2      3  Spring           19  Thursday
# 16606                   12      3  Spring           19  Thursday
# 16607                    4      3  Spring           19  Thursday
# 16608                    7      3  Spring           19  Thursday
# 16609                    3      3  Spring           19  Thursday
#
# [16610 rows x 18 columns]

# %% [markdown]
# Good! Now, we have a dataset with no duplicates and no missing values.

# %% [markdown]
# # Check to see if all data formats are correct

# %%
NY_Citi_Bikes_data_wt_duplicates.dtypes
# Out:
# index                    int64
# Start Time              object
# Stop Time               object
# Start Station ID         int64
# Start Station Name      object
# End Station ID           int64
# End Station Name        object
# Bike ID                  int64
# User Type               object
# Birth Year               int64
# Age                      int64
# Age Groups              object
# Trip Duration            int64
# Trip_Duration_in_min    object
# Month                    int64
# Season                  object
# Temperature              int64
# Weekday                 object
# dtype: object

# %%
NY_Citi_Bikes_data_wt_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16610 entries, 0 to 16609
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 16610 non-null  int64
#  1   Start Time            16610 non-null  object
#  2   Stop Time             16610 non-null  object
#  3   Start Station ID      16610 non-null  int64
#  4   Start Station Name    16610 non-null  object
#  5   End Station ID        16610 non-null  int64
#  6   End Station Name      16610 non-null  object
#  7   Bike ID               16610 non-null  int64
#  8   User Type             16610 non-null  object
#  9   Birth Year            16610 non-null  int64
#  10  Age                   16610 non-null  int64
#  11  Age Groups            16610 non-null  object
#  12  Trip Duration         16610 non-null  int64
#  13  Trip_Duration_in_min  16610 non-null  object
#  14  Month                 16610 non-null  int64
#  15  Season                16610 non-null  object
#  16  Temperature           16610 non-null  int64
#  17  Weekday               16610 non-null  object
# dtypes: int64(9), object(9)
# memory usage: 2.3+ MB

# %%
#NY_Citi_Bikes_data_wt_duplicates['Start Time']=pd.to_datetime(NY_Citi_Bikes_data_wt_duplicates['Start Time'], format='%d-%m-%Y %H:%M')

# %% [markdown]
# Remove all commas from the column 'Trip_Duration_in_min'

# %%
#Remove all commas from the column 
NY_Citi_Bikes_data_wt_duplicates['Trip_Duration_in_min']=\
NY_Citi_Bikes_data_wt_duplicates['Trip_Duration_in_min'].str.replace(',','')

# %%
#Change the column data type to int64
NY_Citi_Bikes_data_wt_duplicates['Trip_Duration_in_min']=\
NY_Citi_Bikes_data_wt_duplicates['Trip_Duration_in_min'].astype('int64')

# %%
NY_Citi_Bikes_data_wt_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16610 entries, 0 to 16609
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 16610 non-null  int64
#  1   Start Time            16610 non-null  object
#  2   Stop Time             16610 non-null  object
#  3   Start Station ID      16610 non-null  int64
#  4   Start Station Name    16610 non-null  object
#  5   End Station ID        16610 non-null  int64
#  6   End Station Name      16610 non-null  object
#  7   Bike ID               16610 non-null  int64
#  8   User Type             16610 non-null  object
#  9   Birth Year            16610 non-null  int64
#  10  Age                   16610 non-null  int64
#  11  Age Groups            16610 non-null  object
#  12  Trip Duration         16610 non-null  int64
#  13  Trip_Duration_in_min  16610 non-null  int64
#  14  Month                 16610 non-null  int64
#  15  Season                16610 non-null  object
#  16  Temperature           16610 non-null  int64
#  17  Weekday               16610 non-null  object
# dtypes: int64(10), object(8)
# memory usage: 2.3+ MB

# %%
NY_Citi_Bikes_data_wt_duplicates
# Out:
#        index      Start Time       Stop Time  Start Station ID  \
# 0          0  01-01-17 00:38    1-1-17 01:03              3194
# 1          3  01-01-17 01:56  01-01-17 02:00              3186
# 2          5  01-01-17 02:22    1-1-17 02:31              3212
# 3          6  01-01-17 02:23  01-01-17 02:27              3186
# 4         11  01-01-17 06:29  01-01-17 06:31              3186
# ...      ...             ...             ...               ...
# 16605  14832    9-3-17 20:48  09-03-17 20:50              3273
# 16606  14833    9-3-17 20:48  09-03-17 21:00              3187
# 16607  14841    9-3-17 21:19  09-03-17 21:23              3275
# 16608  14844    9-3-17 21:23  09-03-17 21:30              3220
# 16609  14851    9-3-17 22:05  09-03-17 22:08              3186
#
#       Start Station Name  End Station ID       End Station Name  Bike ID  \
# 0        McGinley Square            3271    Danforth Light Rail    24668
# 1          Grove St PATH            3270        Jersey & 6th St    24604
# 2        Christ Hospital            3225  Baldwin at Montgomery    24520
# 3          Grove St PATH            3203          Hamilton Park    24512
# 4          Grove St PATH            3211             Newark Ave    24681
# ...                  ...             ...                    ...      ...
# 16605       Manila & 1st            3211             Newark Ave    24609
# 16606          Warren St            3220      5 Corners Library    24528
# 16607     Columbus Drive            3184            Paulus Hook    24617
# 16608  5 Corners Library            3281    Leonard Gordon Park    24528
# 16609      Grove St PATH            3270        Jersey & 6th St    24573
#
#         User Type  Birth Year  Age Age Groups  Trip Duration  \
# 0      Subscriber        1961   60      55-64           1513
# 1      Subscriber        1970   51      45-54            258
# 2      Subscriber        1987   34      25-34            535
# 3      Subscriber        1984   37      35-44            224
# 4      Subscriber        1964   57      55-64            107
# ...           ...         ...  ...        ...            ...
# 16605  Subscriber        1964   57      55-64            129
# 16606  Subscriber        1991   30      25-34            743
# 16607  Subscriber        1960   61      55-64            261
# 16608  Subscriber        1996   25      25-34            424
# 16609  Subscriber        1960   61      55-64            206
#
#        Trip_Duration_in_min  Month  Season  Temperature   Weekday
# 0                        25      1  Winter           10    Sunday
# 1                         4      1  Winter           10    Sunday
# 2                         9      1  Winter           10    Sunday
# 3                         4      1  Winter           10    Sunday
# 4                         2      1  Winter           10    Sunday
# ...                     ...    ...     ...          ...       ...
# 16605                     2      3  Spring           19  Thursday
# 16606                    12      3  Spring           19  Thursday
# 16607                     4      3  Spring           19  Thursday
# 16608                     7      3  Spring           19  Thursday
# 16609                     3      3  Spring           19  Thursday
#
# [16610 rows x 18 columns]

# %% [markdown]
# # Calculate descriptive statistics for “Trip duration” Column

# %%
NY_Citi_Bikes_data_wt_duplicates['Trip_Duration_in_min'].mean()
# Out:
# 9.808127633955449

# %%
NY_Citi_Bikes_data_wt_duplicates['Trip_Duration_in_min'].median()
# Out:
# 5.0

# %%
NY_Citi_Bikes_data_wt_duplicates['Trip_Duration_in_min'].min()
# Out:
# 1

# %%
NY_Citi_Bikes_data_wt_duplicates['Trip_Duration_in_min'].max()
# Out:
# 6515

# %% [markdown]
# # Calculate descriptive statistics for “Age” Column

# %%
NY_Citi_Bikes_data_wt_duplicates['Age'].mean()
# Out:
# 41.728597230583986

# %%
NY_Citi_Bikes_data_wt_duplicates['Age'].median()
# Out:
# 39.0

# %%
NY_Citi_Bikes_data_wt_duplicates['Age'].min()
# Out:
# 22

# %%
NY_Citi_Bikes_data_wt_duplicates['Age'].max()
# Out:
# 90

# %%
NY_Citi_Bikes_data_wt_duplicates.describe()
# Out:
#               index  Start Station ID  End Station ID       Bike ID  \
# count  16610.000000      16610.000000    16610.000000  16610.000000
# mean    9676.590488       3215.808188     3212.052679  25297.985551
# std     5845.921229         34.562818       69.567536    965.164863
# min        0.000000       3183.000000      152.000000  15166.000000
# 25%     4628.250000       3186.000000     3186.000000  24524.000000
# 50%     9294.500000       3203.000000     3202.000000  24679.000000
# 75%    14678.750000       3267.000000     3216.000000  26220.000000
# max    20399.000000       3281.000000     3442.000000  29296.000000
#
#          Birth Year           Age  Trip Duration  Trip_Duration_in_min  \
# count  16610.000000  16610.000000   16610.000000          16610.000000
# mean    1979.271403     41.728597     588.604576              9.808128
# std       10.074939     10.074939    4430.504597             73.840871
# min     1931.000000     22.000000      61.000000              1.000000
# 25%     1974.000000     35.000000     219.000000              4.000000
# 50%     1982.000000     39.000000     311.000000              5.000000
# 75%     1986.000000     47.000000     517.000000              9.000000
# max     1999.000000     90.000000  390893.000000           6515.000000
#
#               Month   Temperature
# count  16610.000000  16610.000000
# mean       2.145635     14.747562
# std        0.823474      2.389600
# min        1.000000      9.000000
# 25%        1.000000     13.000000
# 50%        2.000000     15.000000
# 75%        3.000000     16.000000
# max        3.000000     19.000000

# %% [markdown]
# There is an extreme value in column 'Trip_Duration_in_min'. We will remove this outlier from the dataset and stop it from messing up our result.
# Delete the entire row associated with the outlier

# %%
#Delete the entire row with 'Trip_Duration_in_min' = 6515
NY_Citi_Bikes_data_wt_duplicates =\
NY_Citi_Bikes_data_wt_duplicates.drop(index=[row for row in NY_Citi_Bikes_data_wt_duplicates.index if 6515 == NY_Citi_Bikes_data_wt_duplicates.loc[row, 'Trip_Duration_in_min']])

# %%
NY_Citi_Bikes_data_wt_duplicates
# Out:
#        index      Start Time       Stop Time  Start Station ID  \
# 0          0  01-01-17 00:38    1-1-17 01:03              3194
# 1          3  01-01-17 01:56  01-01-17 02:00              3186
# 2          5  01-01-17 02:22    1-1-17 02:31              3212
# 3          6  01-01-17 02:23  01-01-17 02:27              3186
# 4         11  01-01-17 06:29  01-01-17 06:31              3186
# ...      ...             ...             ...               ...
# 16605  14832    9-3-17 20:48  09-03-17 20:50              3273
# 16606  14833    9-3-17 20:48  09-03-17 21:00              3187
# 16607  14841    9-3-17 21:19  09-03-17 21:23              3275
# 16608  14844    9-3-17 21:23  09-03-17 21:30              3220
# 16609  14851    9-3-17 22:05  09-03-17 22:08              3186
#
#       Start Station Name  End Station ID       End Station Name  Bike ID  \
# 0        McGinley Square            3271    Danforth Light Rail    24668
# 1          Grove St PATH            3270        Jersey & 6th St    24604
# 2        Christ Hospital            3225  Baldwin at Montgomery    24520
# 3          Grove St PATH            3203          Hamilton Park    24512
# 4          Grove St PATH            3211             Newark Ave    24681
# ...                  ...             ...                    ...      ...
# 16605       Manila & 1st            3211             Newark Ave    24609
# 16606          Warren St            3220      5 Corners Library    24528
# 16607     Columbus Drive            3184            Paulus Hook    24617
# 16608  5 Corners Library            3281    Leonard Gordon Park    24528
# 16609      Grove St PATH            3270        Jersey & 6th St    24573
#
#         User Type  Birth Year  Age Age Groups  Trip Duration  \
# 0      Subscriber        1961   60      55-64           1513
# 1      Subscriber        1970   51      45-54            258
# 2      Subscriber        1987   34      25-34            535
# 3      Subscriber        1984   37      35-44            224
# 4      Subscriber        1964   57      55-64            107
# ...           ...         ...  ...        ...            ...
# 16605  Subscriber        1964   57      55-64            129
# 16606  Subscriber        1991   30      25-34            743
# 16607  Subscriber        1960   61      55-64            261
# 16608  Subscriber        1996   25      25-34            424
# 16609  Subscriber        1960   61      55-64            206
#
#        Trip_Duration_in_min  Month  Season  Temperature   Weekday
# 0                        25      1  Winter           10    Sunday
# 1                         4      1  Winter           10    Sunday
# 2                         9      1  Winter           10    Sunday
# 3                         4      1  Winter           10    Sunday
# 4                         2      1  Winter           10    Sunday
# ...                     ...    ...     ...          ...       ...
# 16605                     2      3  Spring           19  Thursday
# 16606                    12      3  Spring           19  Thursday
# 16607                     4      3  Spring           19  Thursday
# 16608                     7      3  Spring           19  Thursday
# 16609                     3      3  Spring           19  Thursday
#
# [16609 rows x 18 columns]

# %%
NY_Citi_Bikes_data_wt_duplicates.describe()
# Out:
#               index  Start Station ID  End Station ID       Bike ID  \
# count  16609.000000      16609.000000    16609.000000  16609.000000
# mean    9676.092179       3215.810163     3212.038834  25298.023722
# std     5845.744439         34.562921       69.546743    965.181382
# min        0.000000       3183.000000      152.000000  15166.000000
# 25%     4628.000000       3186.000000     3186.000000  24524.000000
# 50%     9294.000000       3203.000000     3202.000000  24679.000000
# 75%    14678.000000       3267.000000     3216.000000  26220.000000
# max    20399.000000       3281.000000     3426.000000  29296.000000
#
#          Birth Year           Age  Trip Duration  Trip_Duration_in_min  \
# count  16609.000000  16609.000000   16609.000000          16609.000000
# mean    1979.271118     41.728882     565.105003              9.416461
# std       10.075176     10.075176    3233.799938             53.894609
# min     1931.000000     22.000000      61.000000              1.000000
# 25%     1974.000000     35.000000     219.000000              4.000000
# 50%     1982.000000     39.000000     311.000000              5.000000
# 75%     1986.000000     47.000000     517.000000              9.000000
# max     1999.000000     90.000000  221604.000000           3693.000000
#
#               Month   Temperature
# count  16609.000000  16609.000000
# mean       2.145584     14.747547
# std        0.823472      2.389671
# min        1.000000      9.000000
# 25%        1.000000     13.000000
# 50%        2.000000     15.000000
# 75%        3.000000     16.000000
# max        3.000000     19.000000

# %%
conn.close()

# %% [markdown]
# # Save the cleaned table into the database

# %%
NY_Citi_Bikes_data_wt_duplicates.to_sql('CleanedNYCitiBikesdata', engine, if_exists='replace')
# Out:
# 16609

# %%
conn = sqlite3.connect('citibikes.db')

# %%
table_list
# Out:
# ['CleanedNYCitiBikesdata', 'NYCitiBikesdata']

# %% [markdown]
# # Top 20 pick-up locations

# %%
Top_20_pickup_locations= pd.read_sql_query(''' SELECT `Start Station Name`, Count(*) as Count
                                                FROM CleanedNYCitiBikesdata
                                                GROUP BY `Start Station Name` 
                                                ORDER BY Count(*) DESC 
                                                limit 20 ''', conn)
Top_20_pickup_locations
# Out:
#    Start Station Name  Count
# 0       Grove St PATH   2103
# 1      Exchange Place   1213
# 2       Hamilton Park   1070
# 3             Sip Ave   1049
# 4        Morris Canal    686
# 5        Newport PATH    623
# 6           City Hall    564
# 7      Van Vorst Park    529
# 8           Warren St    492
# 9          Newark Ave    486
# 10    Jersey & 6th St    472
# 11       Brunswick St    471
# 12        Dixon Mills    464
# 13       Jersey & 3rd    456
# 14   Marin Light Rail    452
# 15        Paulus Hook    412
# 16    McGinley Square    389
# 17   Monmouth and 6th    380
# 18   Essex Light Rail    379
# 19    Brunswick & 6th    373

# %%
#plt.figure(figsize=(8,6)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.barplot(data=Top_20_pickup_locations, x="Start Station Name", y= "Count")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Trip duration By age group

# %%
trip_duration_by_agegroup=pd.read_sql_query(''' SELECT `Age Groups`, 
                                                AVG(`Trip_Duration_in_min`) as `Average Trip Duration in min`
                                                FROM CleanedNYCitiBikesdata
                                                GROUP BY `Age Groups`
                                                ORDER BY `Average Trip Duration in min` DESC
                                                ''', conn)
trip_duration_by_agegroup
# Out:
#   Age Groups  Average Trip Duration in min
# 0        75+                     57.276596
# 1      18-24                     11.826923
# 2      55-64                     10.353667
# 3      35-44                      9.656167
# 4      25-34                      9.217238
# 5      45-54                      8.192638
# 6      65-74                      7.472581

# %%
ax=sns.barplot(data=trip_duration_by_agegroup, x="Age Groups", y= "Average Trip Duration in min")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Bike rental by age group

# %%
Bike_rental_by_agegroup=pd.read_sql_query(''' 
                                            SELECT `Age Groups`, 
                                            Count(`Bike ID`) as `Count of Bike ID`
                                            FROM CleanedNYCitiBikesdata 
                                            GROUP BY `Age Groups`
                                            ORDER BY `Count of Bike ID` DESC
                                            ''', conn)
Bike_rental_by_agegroup
# Out:
#   Age Groups  Count of Bike ID
# 0      35-44              7556
# 1      25-34              3968
# 2      45-54              2907
# 3      55-64              1459
# 4      65-74               620
# 5      18-24                52
# 6        75+                47

# %%
ax=sns.barplot(data=Bike_rental_by_agegroup, x="Age Groups", y= "Count of Bike ID")
plt.tight_layout()
plt.show()

# %% [markdown]
# # User type by weekday

# %%
User_type_by_weekday=pd.read_sql_query(''' 
                                            SELECT `Weekday` , `User Type`,  
                                            count(`Bike ID`) as `Count of Bike ID`                                        
                                            FROM CleanedNYCitiBikesdata 
                                            GROUP BY  `Weekday`, `User Type`
                                            ORDER BY `Count of Bike ID`
                                            ''', conn)
User_type_by_weekday
# Out:
#       Weekday      User Type  Count of Bike ID
# 0    Thursday  One-time user                16
# 1      Friday  One-time user                22
# 2     Tuesday  One-time user                28
# 3   Wednesday  One-time user                41
# 4      Monday  One-time user                54
# 5      Sunday  One-time user                63
# 6    Saturday  One-time user                95
# 7    Saturday     Subscriber              1445
# 8      Sunday     Subscriber              1470
# 9      Friday     Subscriber              2385
# 10    Tuesday     Subscriber              2403
# 11     Monday     Subscriber              2451
# 12   Thursday     Subscriber              2887
# 13  Wednesday     Subscriber              3249

# %%
ax=sns.barplot(data=User_type_by_weekday, x="Weekday", y="Count of Bike ID", hue="User Type")
plt.tight_layout()
plt.show()
